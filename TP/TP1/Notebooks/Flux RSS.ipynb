# %% [markdown]
# ### 1. Installer le package feedparser

# %%
# !pip install feedparser
# Out:
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=7accf674a19bacda81bed2ad228e53002ec102249fdd90ff519cb3b4333461fc
#   Stored in directory: c:\users\syrin\appdata\local\pip\cache\wheels\65\7a\a7\78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# ...

# %% [markdown]
# ### 2. Importer la bibliothèque feedparser

# %%
import feedparser

# %% [markdown]
# ### 3. Utiliser la fonction feedparser.parse et spécifier l'URL ( https://www.france24.com/fr/afrique/rss)

# %%
feed = feedparser.parse('https://www.france24.com/fr/afrique/rss')

# %% [markdown]
# ### 4. Afficher le contenu

# %%
feed
# Out:
# {'bozo': False,
#  'entries': [{'tags': [{'term': 'Afrique', 'scheme': None, 'label': None}],
#    'title': 'Burkina Faso : au moins 11 soldats tués et 50 civils portés disparus après une attaque',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://www.france24.com/fr/afrique/rss',
#     'value': 'Burkina Faso : au moins 11 soldats tués et 50 civils portés disparus après une attaque'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.france24.com/fr/afrique/20220927-burkina-faso-au-moins-11-soldats-tu%C3%A9s-et-50-civils-port%C3%A9s-disparus-apr%C3%A8s-une-attaque'},
#     {'type': 'image/jpeg',
#      'length': '0',
#      'href': 'https://s.france24.com/media/display/e654b7cc-3eb3-11ed-bb84-005056bfa79e/w:1024/p:16x9/000_1AL80K.jpg',
#      'rel': 'enclosure'}],
# ...
